# %% [markdown]
# # 03 - Error Analysis Deep Dive
#
# Complements `scripts/10_analyze_failures.py`: load `outputs/examples/main_system_eval_rows.csv` and `outputs/examples/failure_analysis.csv` for interactive slicing (by intent, by message length, by retrieval score) beyond the top-5 categorized summary the script produces.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
eval_df = pd.read_csv('../outputs/examples/main_system_eval_rows.csv')
failures = pd.read_csv('../outputs/examples/failure_analysis.csv')
eval_df.head()

# %%
failures.groupby('failure_category')['n_examples'].first().sort_values(ascending=False)
